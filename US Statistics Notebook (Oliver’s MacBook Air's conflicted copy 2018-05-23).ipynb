# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline


pd.options.mode.chained_assignment = None

df = pd.read_csv('Data/real_estate_db.csv', encoding='ISO-8859-1',index_col='UID')
df.head()
# Out:
#         BLOCKID  SUMLEVEL  COUNTYID  STATEID   state state_ab         city  \
# UID
# 220336      NaN       140        16        2  Alaska       AK     Unalaska
# 220342      NaN       140        20        2  Alaska       AK  Eagle River
# 220343      NaN       140        20        2  Alaska       AK         Jber
# 220345      NaN       140        20        2  Alaska       AK    Anchorage
# 220347      NaN       140        20        2  Alaska       AK    Anchorage
#
#                   place  type primary    ...     female_age_mean  \
# UID                                      ...
# 220336    Unalaska City  City   tract    ...            32.78177
# 220342        Anchorage  City   tract    ...            38.97956
# 220343        Anchorage  City   tract    ...            22.20427
# 220345  Point Mackenzie  City   tract    ...            37.00750
# 220347        Anchorage  City   tract    ...            34.96611
#
#         female_age_median  female_age_stdev  female_age_sample_weight  \
# UID
# 220336           31.91667          19.31875                 440.46429
# 220342           39.66667          20.05513                 466.65478
# 220343           23.16667          13.86575                 887.67805
# 220345           34.00000          22.06347                 281.49420
# 220347           31.75000          20.49887                 655.98066
#
#         female_age_samples  pct_own  married  married_snp  separated  divorced
# UID
# 220336              1894.0  0.25053  0.47388      0.30134    0.03443   0.09802
# 220342              1947.0  0.94989  0.52381      0.01777    0.00782   0.13575
# 220343              3570.0  0.00759  0.50459      0.06676    0.01000   0.01838
# 220345              1049.0  0.20247  0.44428      0.05933    0.00000   0.21563
# 220347              2905.0  0.56936  0.51034      0.08315    0.06731   0.08711
#
# [5 rows x 79 columns]

# %%
df[df.columns.drop(list(df.filter(regex='mean')))]
# Out:
#         SUMLEVEL  COUNTYID  STATEID    state state_ab           city  \
# UID
# 220336       140        16        2   Alaska       AK       Unalaska
# 220342       140        20        2   Alaska       AK    Eagle River
# 220345       140        20        2   Alaska       AK      Anchorage
# 220347       140        20        2   Alaska       AK      Anchorage
# 220348       140        20        2   Alaska       AK      Anchorage
# 220349       140        20        2   Alaska       AK      Anchorage
# 220350       140        20        2   Alaska       AK      Anchorage
# 220352       140        20        2   Alaska       AK      Anchorage
# 220353       140        20        2   Alaska       AK      Anchorage
# 220354       140        20        2   Alaska       AK      Anchorage
# 220355       140        20        2   Alaska       AK      Anchorage
# 220356       140        20        2   Alaska       AK      Anchorage
# 220358       140        20        2   Alaska       AK      Anchorage
# 220359       140        20        2   Alaska       AK      Anchorage
# 220360       140        20        2   Alaska       AK      Anchorage
# 220361       140        20        2   Alaska       AK      Anchorage
# 220364       140        20        2   Alaska       AK      Anchorage
# 220365       140        20        2   Alaska       AK      Anchorage
# 220366       140        20        2   Alaska       AK      Anchorage
# 220367       140        20        2   Alaska       AK      Anchorage
# 220369       140        20        2   Alaska       AK      Anchorage
# 220372       140        20        2   Alaska       AK      Anchorage
# 220373       140        20        2   Alaska       AK      Anchorage
# 220375       140        20        2   Alaska       AK      Anchorage
# 220378       140        20        2   Alaska       AK      Anchorage
# 220380       140        20        2   Alaska       AK      Anchorage
# 220381       140        20        2   Alaska       AK      Anchorage
# 220382       140        20        2   Alaska       AK      Anchorage
# 220386       140        20        2   Alaska       AK      Anchorage
# 220387       140        20        2   Alaska       AK      Anchorage
# ...          ...       ...      ...      ...      ...            ...
# 294274       140        23       56  Wyoming       WY          Afton
# 294275       140        23       56  Wyoming       WY   Diamondville
# 294276       140        23       56  Wyoming       WY   Diamondville
# 294282       140        25       56  Wyoming       WY         Casper
# 294285       140        25       56  Wyoming       WY         Casper
# 294287       140        25       56  Wyoming       WY         Casper
# 294290       140        25       56  Wyoming       WY        Midwest
# 294291       140        25       56  Wyoming       WY         Casper
# 294292       140        25       56  Wyoming       WY         Casper
# 294295       140        27       56  Wyoming       WY    Lance Creek
# 294296       140        29       56  Wyoming       WY         Powell
# 294299       140        29       56  Wyoming       WY           Cody
# 294300       140        29       56  Wyoming       WY           Cody
# 294301       140        31       56  Wyoming       WY      Wheatland
# 294305       140        33       56  Wyoming       WY       Sheridan
# 294306       140        33       56  Wyoming       WY       Sheridan
# 294307       140        33       56  Wyoming       WY      Clearmont
# 294308       140        33       56  Wyoming       WY         Dayton
# 294312       140        37       56  Wyoming       WY    Green River
# 294313       140        37       56  Wyoming       WY    Green River
# 294315       140        37       56  Wyoming       WY   Rock Springs
# 294316       140        37       56  Wyoming       WY   Rock Springs
# 294317       140        37       56  Wyoming       WY   Rock Srpings
# 294318       140        37       56  Wyoming       WY   Rock Springs
# 294321       140        37       56  Wyoming       WY   Rock Springs
# 294326       140        39       56  Wyoming       WY        Jackson
# 294327       140        41       56  Wyoming       WY  Mountain View
# 294331       140        43       56  Wyoming       WY        Worland
# 294333       140        45       56  Wyoming       WY          Upton
# 294334       140        45       56  Wyoming       WY      Newcastle
#
#                      place  type primary  zip_code    ...     \
# UID                                                   ...
# 220336       Unalaska City  City   tract     99685    ...
# 220342           Anchorage  City   tract     99577    ...
# 220345     Point Mackenzie  City   tract     99501    ...
# 220347           Anchorage  City   tract     99504    ...
# 220348           Anchorage  City   tract     99504    ...
# 220349           Anchorage  City   tract     99504    ...
# 220350     Point Mackenzie  City   tract     99508    ...
# 220352     Point Mackenzie  City   tract     99508    ...
# 220353     Point Mackenzie  City   tract     99501    ...
# 220354     Point Mackenzie  City   tract     99501    ...
# 220355     Point Mackenzie  City   tract     99501    ...
# 220356     Point Mackenzie  City   tract     99501    ...
# 220358     Point Mackenzie  City   tract     99503    ...
# 220359     Point Mackenzie  City   tract     99508    ...
# 220360     Point Mackenzie  City   tract     99508    ...
# 220361     Point Mackenzie  City   tract     99508    ...
# 220364           Anchorage  City   tract     99504    ...
# 220365           Anchorage  City   tract     99504    ...
# 220366     Point Mackenzie  City   tract     99507    ...
# 220367     Point Mackenzie  City   tract     99507    ...
# 220369     Point Mackenzie  City   tract     99517    ...
# 220372     Point Mackenzie  City   tract     99517    ...
# 220373     Point Mackenzie  City   tract     99502    ...
# 220375     Point Mackenzie  City   tract     99502    ...
# 220378     Point Mackenzie  City   tract     99518    ...
# 294287                 555.50380              2573.0  0.71884  0.57375
# 294290                 722.18105              2978.0  0.77690  0.59083
# 294291                 907.57444              3525.0  0.69962  0.63769
# 294292                 448.71243              1880.0  0.90445  0.68478
# 294295                 309.60253              1352.0  0.72403  0.61605
# 294296                 612.86967              2667.0  0.79114  0.65319
# 294299                 683.49854              2908.0  0.64835  0.67152
# 294300                 704.69877              2550.0  0.72041  0.50464
# 294301                 241.87631              1046.0  0.74066  0.54151
# 294305                 495.22618              1921.0  0.54350  0.57399
# 294306                 725.27908              3048.0  0.71525  0.55668
# 294307                 854.33412              3360.0  0.84461  0.72296
# 294308                 580.67316              2323.0  0.74006  0.58897
# 294312                 602.35739              2512.0  0.67133  0.53480
# 294313                 378.42358              1710.0  0.76547  0.64184
# 294315                 551.06097              2311.0  0.66156  0.40703
# 294316                 784.69752              3547.0  0.82831  0.61557
# 294317                 507.75890              2143.0  0.64877  0.61205
# 294318                 400.27505              1572.0  0.47548  0.53455
# 294321                 269.57276              1218.0  0.86847  0.61474
# 294326                 952.78660              4026.0  0.54379  0.50483
# 294327                 785.48674              3234.0  0.78639  0.52106
# 294331                 322.07543              1314.0  0.68378  0.47577
# 294333                 335.79905              1444.0  0.82450  0.54247
# 294334                 506.70228              2013.0  0.81300  0.61521
#
#         married_snp  separated  divorced
# UID
# 220336      0.30134    0.03443   0.09802
# 220342      0.01777    0.00782   0.13575
# 220345      0.05933    0.00000   0.21563
# 220347      0.08315    0.06731   0.08711
# 220348      0.04615    0.02418   0.10242
# 220349      0.07853    0.01723   0.08894
# 220350      0.08381    0.00645   0.11945
# 220352      0.06467    0.02304   0.13622
# 220353      0.04506    0.01186   0.17154
# 220354      0.07515    0.01318   0.15162
# 220355      0.11301    0.06678   0.19521
# 220356      0.04689    0.00000   0.11328
# 220358      0.01482    0.00494   0.20575
# 220359      0.07283    0.02994   0.10098
# 220360      0.02404    0.00506   0.03289
# 220361      0.07542    0.02747   0.14106
# 220364      0.08280    0.01790   0.09213
# 220365      0.05042    0.01765   0.13487
# 220366      0.01101    0.00326   0.10848
# 220367      0.02976    0.00350   0.08884
# 220369      0.05695    0.00662   0.19139
# 220372      0.09919    0.04355   0.17581
# 220373      0.03106    0.01806   0.06067
# 220375      0.03979    0.00439   0.11779
# 220378      0.04836    0.00000   0.14187
# 220380      0.04431    0.00399   0.10058
# 220381      0.00933    0.00000   0.09207
# 220382      0.03855    0.02086   0.06522
# 220386      0.04458    0.00641   0.07847
# 220387      0.03581    0.00480   0.06769
# ...             ...        ...       ...
# 294274      0.03606    0.02315   0.04363
# 294275      0.02514    0.00559   0.08799
# 294276      0.03592    0.01221   0.07040
# 294282      0.08333    0.06012   0.12861
# 294285      0.02902    0.01055   0.16201
# 294287      0.01681    0.00217   0.11876
# 294290      0.03226    0.00722   0.18039
# 294291      0.03812    0.01285   0.14304
# 294292      0.00000    0.00000   0.06170
# 294295      0.04121    0.02061   0.10195
# 294296      0.03520    0.00999   0.05804
# 294299      0.03289    0.00916   0.09825
# 294300      0.02958    0.00116   0.06903
# 294301      0.04151    0.00849   0.16698
# 294305      0.00000    0.00000   0.07565
# 294306      0.07894    0.04452   0.11749
# 294307      0.00977    0.00698   0.09839
# 294308      0.04727    0.01437   0.11260
# 294312      0.01981    0.00623   0.10470
# 294313      0.01896    0.01422   0.08802
# 294315      0.02871    0.00000   0.24079
# 294316      0.04087    0.02149   0.12438
# 294317      0.00942    0.00000   0.12869
# 294318      0.10741    0.03497   0.10575
# 294321      0.06211    0.00000   0.10842
# 294326      0.05769    0.04890   0.08726
# 294327      0.00957    0.00153   0.19755
# 294331      0.02643    0.01211   0.29185
# 294333      0.06852    0.00906   0.14609
# 294334      0.01459    0.00768   0.10215
#
# [37940 rows x 71 columns]

# %%
df.isnull().sum()
# Out:
# SUMLEVEL                       0
# COUNTYID                       0
# STATEID                        0
# state                          0
# state_ab                       0
# city                           0
# place                          0
# type                           0
# primary                        0
# zip_code                       0
# area_code                      0
# lat                            0
# lng                            0
# ALand                          0
# AWater                         0
# pop                            0
# male_pop                       0
# female_pop                     0
# rent_mean                      0
# rent_median                    0
# rent_stdev                     0
# rent_sample_weight             0
# rent_samples                   0
# rent_gt_10                     0
# rent_gt_15                     0
# rent_gt_20                     0
# rent_gt_25                     0
# rent_gt_30                     0
# rent_gt_35                     0
# rent_gt_40                     0
#                               ..
# hc_mean                        0
# hc_median                      0
# hc_stdev                       0
# hc_samples                     0
# hc_sample_weight               0
# home_equity_second_mortgage    0
# second_mortgage                0
# home_equity                    0
# debt                           0
# second_mortgage_cdf            0
# home_equity_cdf                0
# debt_cdf                       0
# hs_degree                      0
# hs_degree_male                 0
# hs_degree_female               0
# male_age_mean                  0
# male_age_median                0
# male_age_stdev                 0
# male_age_sample_weight         0
# male_age_samples               0
# female_age_mean                0
# female_age_median              0
# female_age_stdev               0
# female_age_sample_weight       0
# female_age_samples             0
# pct_own                        0
# married                        0
# married_snp                    0
# separated                      0
# divorced                       0
# Length: 78, dtype: int64

# %%
df.drop(['BLOCKID'], axis=1, inplace=True)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37940 entries, 220336 to 294334
# Data columns (total 78 columns):
# SUMLEVEL                       37940 non-null int64
# COUNTYID                       37940 non-null int64
# STATEID                        37940 non-null int64
# state                          37940 non-null object
# state_ab                       37940 non-null object
# city                           37940 non-null object
# place                          37940 non-null object
# type                           37940 non-null object
# primary                        37940 non-null object
# zip_code                       37940 non-null int64
# area_code                      37940 non-null int64
# lat                            37940 non-null float64
# lng                            37940 non-null float64
# ALand                          37940 non-null int64
# AWater                         37940 non-null int64
# pop                            37940 non-null int64
# male_pop                       37940 non-null int64
# female_pop                     37940 non-null int64
# rent_mean                      37940 non-null float64
# rent_median                    37940 non-null float64
# rent_stdev                     37940 non-null float64
# rent_sample_weight             37940 non-null float64
# rent_samples                   37940 non-null float64
# rent_gt_10                     37940 non-null float64
# rent_gt_15                     37940 non-null float64
# rent_gt_20                     37940 non-null float64
# rent_gt_25                     37940 non-null float64
# rent_gt_30                     37940 non-null float64
# rent_gt_35                     37940 non-null float64
# rent_gt_40                     37940 non-null float64
# rent_gt_50                     37940 non-null float64
# universe_samples               37940 non-null int64
# used_samples                   37940 non-null int64
# hi_mean                        37940 non-null float64
# hi_median                      37940 non-null float64
# hi_stdev                       37940 non-null float64
# hi_sample_weight               37940 non-null float64
# hi_samples                     37940 non-null float64
# family_mean                    37940 non-null float64
# family_median                  37940 non-null float64
# family_stdev                   37940 non-null float64
# family_sample_weight           37940 non-null float64
# family_samples                 37940 non-null float64
# hc_mortgage_mean               37940 non-null float64
# hc_mortgage_median             37940 non-null float64
# hc_mortgage_stdev              37940 non-null float64
# hc_mortgage_sample_weight      37940 non-null float64
# hc_mortgage_samples            37940 non-null float64
# hc_mean                        37940 non-null float64
# hc_median                      37940 non-null float64
# hc_stdev                       37940 non-null float64
# hc_samples                     37940 non-null float64
# hc_sample_weight               37940 non-null float64
# home_equity_second_mortgage    37940 non-null float64
# second_mortgage                37940 non-null float64
# home_equity                    37940 non-null float64
# debt                           37940 non-null float64
# second_mortgage_cdf            37940 non-null float64
# home_equity_cdf                37940 non-null float64
# debt_cdf                       37940 non-null float64
# hs_degree                      37940 non-null float64
# hs_degree_male                 37940 non-null float64
# hs_degree_female               37940 non-null float64
# male_age_mean                  37940 non-null float64
# male_age_median                37940 non-null float64
# male_age_stdev                 37940 non-null float64
# male_age_sample_weight         37940 non-null float64
# male_age_samples               37940 non-null float64
# female_age_mean                37940 non-null float64
# female_age_median              37940 non-null float64
# female_age_stdev               37940 non-null float64
# female_age_sample_weight       37940 non-null float64
# female_age_samples             37940 non-null float64
# pct_own                        37940 non-null float64
# married                        37940 non-null float64
# married_snp                    37940 non-null float64
# separated                      37940 non-null float64
# divorced                       37940 non-null float64
# dtypes: float64(60), int64(12), object(6)
# memory usage: 22.9+ MB

# %%
plt.style.use('fivethirtyeight')
plt.hist(df['debt'], bins = 20, edgecolor = 'k');
plt.xlabel('Debt'); plt.ylabel('Number of People'); 
plt.title('Debt Distribution');

# %%
df['debt'].describe()
# Out:
# count    37940.000000
# mean         0.630553
# std          0.149351
# min          0.013590
# 25%          0.540108
# 50%          0.648570
# 75%          0.737097
# max          0.979920
# Name: debt, dtype: float64

# %%
df['type'].value_counts()
# Out:
# City       21063
# Town        5151
# CDP         5070
# Village     4497
# Borough     1699
# Urban        460
# Name: type, dtype: int64

# %%
# Create a list of boroughs with more than 100 observations
location_type = df.dropna(subset=['debt'])
location_type = location_type['type'].value_counts()
location_type = list(location_type[location_type.values > 100].index)

# Plot of distribution of scores for building categories
plt.figure(figsize=(10, 8))

# Plot each building
for location in location_type:
    # Select the building type
    subset = df[df['type'] == location]
    
    # Density plot of Energy Star scores
    sns.kdeplot(subset['debt'].dropna(),
               label = location, shade = False, alpha = 0.8);
    
# label the plot
plt.xlabel('Percentage of Homes with Some Type of Debt', size = 20); plt.ylabel('Density', size = 20); 
plt.title('Density Plot of Debt % by Location Type', size = 28);

# %%
# Create a list of boroughs with more than 100 observations
location_type_div = df.dropna(subset=['divorced'])
location_type_div = location_type_div['type'].value_counts()
location_type_div = list(location_type_div[location_type_div.values > 100].index)

# Plot of distribution of scores for building categories
plt.figure(figsize=(10, 8))

# Plot each building
for location in location_type_div:
    # Select the building type
    subset = df[df['type'] == location]
    
    # Density plot of Energy Star scores
    sns.kdeplot(subset['divorced'].dropna(),
               label = location, shade = False, alpha = 0.8);
    
# label the plot
plt.xlabel('Percentage of Homes with Divorced People', size = 20); plt.ylabel('Density', size = 20); 
plt.title('Density Plot of Divorce % by Location Type', size = 28);

# %%
# Create a list of boroughs with more than 100 observations
features = df.dropna(subset=['pop'])
features = features['type'].value_counts()
features = list(features[features.values > 100].index)

# %%
plt.figure(figsize=(10, 8))

df_copy = df

# Extract the building types
df_copy['type'] = df_copy.dropna(subset = ['pop'])['type']

# Limit to building types with more than 100 observations (from previous code)
df_copy = df_copy[df_copy['type'].isin(features)]

# Use seaborn to plot a scatterplot of Score vs Log Source EUI
sns.lmplot('rent_median', 'pop', 
          hue = 'type', data = df_copy,
          scatter_kws = {'alpha': 0.75, 's': 60}, fit_reg = False,
          size = 12, aspect = 1.2);

# Plot labeling
plt.xlabel("Median Rent", size = 28)
plt.ylabel('Population', size = 28)
plt.title('Median Rent vs Population', size = 36);

# %%
df.loc[df['pop'] > 50000]
# Out:
#         SUMLEVEL  COUNTYID  STATEID  state state_ab  city        place  type  \
# UID
# 284935       140       157       48  Texas       TX  Katy  Cinco Ranch  Town
#
#        primary  zip_code    ...     female_age_mean  female_age_median  \
# UID                         ...
# 284935   tract     77494    ...            32.00601           33.83333
#
#         female_age_stdev  female_age_sample_weight  female_age_samples  \
# UID
# 284935          19.73472                 6197.9952             27250.0
#
#         pct_own  married  married_snp  separated  divorced
# UID
# 284935  0.88447  0.73474      0.02058    0.00405   0.03036
#
# [1 rows x 78 columns]

# %%
high_pop = df.sort_values(by=['pop'], ascending=False)
high_pop = high_pop.head(750)

low_pop = df.sort_values(by=['pop'], ascending=False)
low_pop = low_pop.tail(750)

high_rent = df.sort_values(by=['rent_median'], ascending=False)
high_rent = high_rent.head(750)

low_rent = df.sort_values(by=['rent_median'], ascending=False)
low_rent = low_rent.tail(750)

# %%
correlations = df.corr()['rent_median'].dropna().sort_values()
correlations.head(10)
# Out:
# debt_cdf               -0.454160
# home_equity_cdf        -0.416088
# rent_sample_weight     -0.385243
# divorced               -0.369303
# hc_sample_weight       -0.295854
# hi_sample_weight       -0.274791
# family_sample_weight   -0.208167
# STATEID                -0.204581
# female_age_stdev       -0.190427
# second_mortgage_cdf    -0.182932
# Name: rent_median, dtype: float64

# %%
correlations.tail(10)
# Out:
# rent_stdev            0.580078
# hi_stdev              0.613252
# family_median         0.669062
# family_mean           0.669943
# hc_mortgage_mean      0.726818
# hi_mean               0.727599
# hc_mortgage_median    0.728563
# hi_median             0.730401
# rent_mean             0.975979
# rent_median           1.000000
# Name: rent_median, dtype: float64
